# %% [markdown]
# ## EXERCISES

# %% [markdown]
# #### Exercise 1
# Adapted from [TCS] Appendix D, Exercise 2
#
# Open help for the math module.
#
# - What are the constants in the math module?
#
#   #
#   - The constants of the math module are math.inf, math.nan, math.pi and math.tau
#
#
#
# - What's does `math.exp` do? What about `math.pow`?
#
#   #
#   - The Math.exp method returns Euler's number raised to the power of x, where x is the number passed to it.
#   - The Math.pow method returns the value of x raised to the power of y. If x is negative and y is not an integer, it raises a ValueError, and it converts both arguments into floats.
#
# - How do you calculate logarithms? Logarithms base 10? Natural Logarithms?
#
#    #
#    - When calculating logarithms, we divide the provided integer 'a' by the base 'b' several times until 'a' is equal to or less than 1. Every division increases the response by one. The logarithm of 'a' to base 'b' is represented in the final result. Set 'ans', a variable, to zero initially.
#
#    #
#    Logarithms base 10
#
#    In Python's math module, for example, you may use math.log10(x) to determine the logarithm of 'x' to the base 10. You can also use the logarithm function found in most scientific calculators and computer languages to calculate logarithms base 10.
#
#    #
#    Natural Logarithms
#
#    ln(x), the natural logarithm function, can be used to calculate natural logarithms. In this case, 'x' stands for the number whose natural logarithm you must discover. You would use math.log(x) in Python's math module to get the natural logarithm of 'x'.

# %% [markdown]
# #### Exercise 2
# - Create your own module.
# - Place variables and functions inside it.
# - Import your module and use the variabls and functions you've created in the module.
# - Try to add docstrings for the module and the functions
#
# [あ]

# %%
# %%writefile my_module.py

def divide(a, b):  # this function use to divide two variables
    return a / b

def multiply(a, b): # this function use to multiply two variables
    return a * b

test = "It's working"
# Out:
# Overwriting my_module.py

# %%
if __name__ == "__main__":
    import my_module as m

    print(m.test)
    print(m.divide(3, 1098))
    print(m.multiply(3204, 1240))
# Out:
# It's working
# 0.00273224043715847
# 3972960
