# %% [markdown]
# # CHAPTER 6  - `Strings`

# %% [markdown]
# ## EXERCISES

# %% [markdown]
# #### Exercise 1

# %% [markdown]
# Given the code below
#
#     text = 'Business Analytics'
#
# What will the following expressions produce?
#
#     text[4]
#     text[2:4]
#     text[:4]
#     text[4:]
#     text[-2]
#     text[-4:-2]
#     text[-2:]
#     text[:-2]

# %%
texts = 'Business Analytics'

print(text[4])
print(text[2:4])
print(text[:4])
print(text[4:])
print(text[-2])
print(text[-4:-2])
print(text[-2:])
print(text[:-2])
# Out:
# n
# si
# Busi
# ness Analytics
# c
# ti
# cs
# Business Analyti

# %% [markdown]
# #### Exercise 2

# %% [markdown]
# Given the code below:
#
#     phrase = 'One Ring to rule them all'
#
# What string slicing expression gives out the following words:
#
#     'One '
#     'Ring'
#     'all'
#     'them'
#     'One Ring to rule them all'

# %%
phrase = 'One Ring to rule them all'

substring1 = phrase[:4]
print(substring1)

substring2 = phrase[4:8]
print(substring2)

substring3 = phrase[-3:]
print(substring3)

substring4 = phrase[-8:-4]
print(substring4)

substring5 = phrase[:]
print(substring5)
# Out:
# One
# Ring
# all
# them
# One Ring to rule them all

# %% [markdown]
# ## CHALLENGE

# %% [markdown]
# Write a program which repeatedly reads a **full name**, then does the following:
# - strips the name of any trailing spaces
# - capitalizes the first letter
# - puts the rest into smaller letters

# %%
def format_name(name):
    return ' '.join(word.capitalize() for word in name.strip().split())

def main():
    while True:
        full_name = input("Enter a full name: ")
        formatted_name = format_name(full_name)
        print("Full Name:", formatted_name)
        break
if __name__ == "__main__":
    main()
# Out:
# Enter a full name: Christian paul salinas
# Full Name: Christian Paul Salinas
