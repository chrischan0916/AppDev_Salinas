# %%
# !cp "/content/drive/MyDrive/Colab Notebooks/Chapter1-Exercises.ipynb" ""
# Out:
# Branch 'main' set up to track remote branch 'main' from 'origin'.
# Everything up-to-date

# %% [markdown]
# #### Exercise 1
#
# Each line of code below contains an **error**. Fix the error and explain in a comment the reason for the error.

# %%
Problem: Print('Hello world!')
Answer: print('Hello World!')

#In this code, the first letter of print is capitalized

# %%
Problem: print'Hello world!')
Answer: print('Hello World!')

#In this code, the code was missing a parathesis

# %%
Problem: print('Hello world!)
Answer: print('Hello World!')

#In this code, the code was missing a single quotation

# %%
Problem: print('Hello world!'')
Answer: print('Hello World!')

#In this code, the code has another single quotation

# %% [markdown]
# #### Exercise 2
# What is the output of the code below? [PEW]

# %%
x = 43
x = x + 1
print(x)

#The output is 44 because x assigned 43 and x = x(43) plus 1 equal to 44

# %% [markdown]
# #### Exercise 3
# The code below contains an error. Fix the error and explain in a comment the reason for the error.

# %%
x = 43
x = X + 1 # The Name x is captilized
print(x) #The name "X" is not a defined variable
