# %% [markdown]
# ## EXERCISES

# %% [markdown]
# #### Exercise 1

# %% [markdown]
# Investigate on the difference between `is` and `==` given the following variables.
# ```python
# a = 2
# b = 2.0
# c = a
# ```

# %%
# '==' compares values, returning True if variables have equal values.
# 'is' checks identity, returning True if variables reference the same object in memory.

a = 2
b = 2.0
c = a

print(a is c)  # Output True: 'a' and 'c' point to the same object in memory.
print(a == c)  # Output True: The values referenced by 'a' and 'c' are identical.
print(a is b)  # Output False: 'a' and 'b' are references to distinct objects in memory.
print(a == b)  # Output True: The values referenced by 'a' and 'b' are identical, despite being different objects.
# Out:
# True
# True
# False
# True

# %% [markdown]
# ## CHALLENGES

# %% [markdown]
# #### Challenge 1

# %% [markdown]
# Write a program which repeatedly reads numbers until the user enters "done". Once "done" is entered, print out the total, count, and average of the numbers. If the user enters anything other than a number, detect their mistake using try and except and print an error message and skip to the next number.
#
#     Enter a number: 4
#     Enter a number: 5
#     Enter a number: bad data
#     Invalid input
#     Enter a number: 7
#     Enter a number: done
#     16 3 5.333333333333333
#
# [PEW] E5.1

# %%
total = 0
count = 0

while True:
    try:
        user = input("Enter a number: ")
        if user.lower() == "done":
            break
        number = float(user)
        total += number
        count += 1
    except ValueError:
        print("Invalid input")

if count > 0:
    average = total / count
    print(int(total), count, average)
else:
    print("Invalid Number")
# Out:
# Enter a number: 4
# Enter a number: 5
# Enter a number: bad data
# Invalid input
# Enter a number: 7
# Enter a number: done
# 16 3 5.333333333333333

# %% [markdown]
# #### Challenge 2

# %% [markdown]
# Write another program that prompts for a list of numbers as above and at the end prints out both the maximum and minimum of the numbers instead of the average.
#
# [PEW] E5.2

# %%
maxNum = None
minNum = None

while True:
    try:
        num = input("Enter a number: ")
        if num.lower() == 'done':
            break
        number = int(num)
        if maxNum is None or number > maxNum:
            maxNum = number

        if minNum is None or number < minNum:
            minNum = number
    except ValueError:
        print("Invalid Input.")

if maxNum is not None and minNum is not None:
    print(f"Maximum number: {maxNum}")
    print(f"Minimum number: {minNum}")
else:
    print("No valid numbers.")
# Out:
# Enter a number: 4
# Enter a number:
# Invalid Input.
# Enter a number: 4
# Enter a number:
# Invalid Input.
# Enter a number: 4
# Enter a number: done
# Maximum number: 4
# Minimum number: 4
